# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxamir/DogeBot/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-598e6506ec81> in <cell line: 0>()
#       7 from sklearn.metrics import mean_absolute_error, mean_squared_error
#       8 url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00294/CCPP.zip"
# ----> 9 df = pd.read_csv(url, compression="zip")
#      10 df.head()
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef5f74ed-a2cc-4c43-86d1-081b5c116310" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef5f74ed-a2cc-4c43-86d1-081b5c116310">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-69c66235-fe4f-4326-a041-097877ff6836" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69c66235-fe4f-4326-a041-097877ff6836">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23a6d839-74b9-4a41-b856-5ee9e093ca78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23a6d839-74b9-4a41-b856-5ee9e093ca78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'CCPP.zip',
#  'Folds5x2_pp.xlsx',
#  'Folds5x2_pp.ods',
#  'Readme.txt',
#  'sample_data']

# %%
df=pd.read_csv("CCPP.zip",compression="zip")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f5a6ac581796> in <cell line: 0>()
# ----> 1 df=pd.read_csv("CCPP.zip",compression="zip")
#       2 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import zipfile

with zipfile.ZipFile("CCPP.zip", "r") as z:
    z.extractall("CCPP_extracted")  # استخراج فایل‌ها داخل یک پوشه
    print(z.namelist())  # نمایش لیست فایل‌ها داخل ZIP
# Out:
# ['CCPP/', 'CCPP/Folds5x2_pp.ods', 'CCPP/Folds5x2_pp.xlsx', 'CCPP/Readme.txt', 'CCPP/Readme.txt~']

# %%
import pandas as pd

# خواندن فایل اکسل
df = pd.read_excel("CCPP/Folds5x2_pp.xlsx")

# نمایش چند سطر اول دیتاست
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-7513f4b78a3d> in <cell line: 0>()
#       2
#       3 # خواندن فایل اکسل
# ----> 4 df = pd.read_excel("CCPP/Folds5x2_pp.xlsx")
#       5
#       6 # نمایش چند سطر اول دیتاست
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
import zipfile
import os

# مسیر فایل ZIP
zip_path = "/content/CCPP.zip"

# استخراج فایل‌ها
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/CCPP")

# نمایش فایل‌های داخل فولدر
os.listdir("/content/CCPP")
# Out:
# ['CCPP']

# %%
import os

# نمایش فایل‌های داخل پوشه CCPP
os.listdir("/content/CCPP")
# Out:
# ['CCPP']

# %%
import os

# نمایش محتویات فولدر CCPP به صورت بازگشتی
for root, dirs, files in os.walk("/content/CCPP"):
    print(f"Root: {root}")
    print(f"Dirs: {dirs}")
    print(f"Files: {files}")
# Out:
# Root: /content/CCPP
# Dirs: ['CCPP']
# Files: []
# Root: /content/CCPP/CCPP
# Dirs: []
# Files: ['Folds5x2_pp.xlsx', 'Readme.txt~', 'Folds5x2_pp.ods', 'Readme.txt']

# %%
import pandas as pd

# خواندن فایل اکسل از مسیر جدید
df = pd.read_excel("/content/CCPP/CCPP/Folds5x2_pp.xlsx")

# نمایش چند سطر اول دیتاست
df.head()

# %%
# بررسی نوع داده‌های دیتاست
print(type(df))

# نمایش تعداد سطرها و ستون‌های دیتاست
print(df.shape)

# نمایش چند سطر اول دیتاست
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-91b50b9df6bb> in <cell line: 0>()
#       1 # بررسی نوع داده‌های دیتاست
# ----> 2 print(type(df))
#       3
#       4 # نمایش تعداد سطرها و ستون‌های دیتاست
#       5 print(df.shape)
#
# NameError: name 'df' is not defined

# %%
# بررسی نوع داده‌های دیتاست
print(type(df))

# نمایش تعداد سطرها و ستون‌های دیتاست
print(df.shape)

# نمایش چند سطر اول دیتاست
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dfe8a808935e> in <cell line: 0>()
#       1 # بررسی نوع داده‌های دیتاست
# ----> 2 print(type(df))
#       3
#       4 # نمایش تعداد سطرها و ستون‌های دیتاست
#       5 print(df.shape)
#
# NameError: name 'df' is not defined

# %%
df = pd.read_excel("CCPP_extracted/CCPP/Folds5x2_pp.xlsx")
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.info()
df.isnull().sum()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# ...
